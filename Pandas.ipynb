# %% [markdown]
# # Installation et chargement du package

# %%
#!pip install pandas
import pandas as pd

# %% [markdown]
# # Création des dataframe avec pandas

# %% [markdown]
# ## Création à partir d'un dictionnaire

# %%
# Création du dictionnaire
etudiant = {"Nom":["Mendong","Zibi","Ekounou","Bastos"]
           ,
           "Prenom":["Chloe","Loic","Helene","Nathan"],
           "Notes":[19,18,15,13]}
etudiant
# Out:
# {'Nom': ['Mendong', 'Zibi', 'Ekounou', 'Bastos'],
#  'Prenom': ['Chloe', 'Loic', 'Helene', 'Nathan'],
#  'Notes': [19, 18, 15, 13]}

# %%
# Transformer le dictionnaire en dataframe
df_etudiant=pd.DataFrame(etudiant)
df_etudiant
# Out:
#        Nom  Prenom  Notes
# 0  Mendong   Chloe     19
# 1     Zibi    Loic     18
# 2  Ekounou  Helene     15
# 3   Bastos  Nathan     13

# %% [markdown]
# ## Création à partir d'un fichier csv/excel

# %%
# Importaion du fichier csv
df=pd.read_csv("data/credit_risk_dataset.csv",sep=";")
df
# Out:
#     Id_personne  Age       Nom     Prenom  Revenu Type de domicile  \
# 0             1   40     Akono     Nathan   59000        Locataire
# 1             2   35      Akwa      Aicha   70000     Propriétaire
# 2             3   25    Arnaud      Matin    9600        Locataire
# 3             4   23       Awa      Marie   44000             Pret
# 4             5   24    Dubois   Lachaise   54400             Pret
# 5             6   21    Durand     Bertin    9900        Locataire
# 6             7   44   Ekounou        Eli   77100     Propriétaire
# 7             8   24   Mendong       Zibi   33000        Locataire
# 8             9   24    Moussa     Hamado   24000        Locataire
# 9            10   50  Mvog-ada     Bertin   80000     Propriétaire
# 10           11   22     Mvogo    Melanie   25000        Locataire
# 11           12   21      Neba   Charlène   10000        Locataire
# 12           13   34       Ngo  Stephanie   95000             Pret
# ...

# %%
# Importation du fichier excel
df=pd.read_excel("data/credit_dataset_excel.xlsx")
df
# Out:
#     Id_personne  Age       Nom     Prenom  Revenu Type de domicile  \
# 0             1   40     Akono     Nathan   59000        Locataire
# 1             2   35      Akwa      Aicha   70000     Propriétaire
# 2             3   25    Arnaud      Matin    9600        Locataire
# 3             4   23       Awa      Marie   44000             Pret
# 4             5   24    Dubois   Lachaise   54400             Pret
# 5             6   21    Durand     Bertin    9900        Locataire
# 6             7   44   Ekounou        Eli   77100     Propriétaire
# 7             8   24   Mendong       Zibi   33000        Locataire
# 8             9   24    Moussa     Hamado   24000        Locataire
# 9            10   50  Mvog-ada     Bertin   80000     Propriétaire
# 10           11   22     Mvogo    Melanie   25000        Locataire
# 11           12   21      Neba   Charlène   10000        Locataire
# 12           13   34       Ngo  Stephanie   95000             Pret
# ...

# %% [markdown]
# ## Afficher un dataframe et afficher le type de données et description des colonnes

# %%
#Afficher les 10 premiers éléments
df.head(10)
# Out:
#    Id_personne  Age       Nom    Prenom  Revenu Type de domicile Travail  \
# 0            1   40     Akono    Nathan   59000        Locataire     CDI
# 1            2   35      Akwa     Aicha   70000     Propriétaire     CDI
# 2            3   25    Arnaud     Matin    9600        Locataire     CDD
# 3            4   23       Awa     Marie   44000             Pret     CDI
# 4            5   24    Dubois  Lachaise   54400             Pret     CDI
# 5            6   21    Durand    Bertin    9900        Locataire     CDD
# 6            7   44   Ekounou       Eli   77100     Propriétaire     CDI
# 7            8   24   Mendong      Zibi   33000        Locataire     CDI
# 8            9   24    Moussa    Hamado   24000        Locataire     CDI
# 9           10   50  Mvog-ada    Bertin   80000     Propriétaire     CDI
#
#   Grade du pret  Montant du prêt  Taux_interet  Statut_du_pret  \
# 0             D            35000         16.02               1
# ...

# %%
#Afficher les 5 derniers éléments du tableau
df.tail(5)
# Out:
#     Id_personne  Age       Nom  Prenom  Revenu Type de domicile  \
# 15           16   32     Petit  Prince  500000     Propriétaire
# 16           17   23   Richard  Arnaud  120000        Locataire
# 17           18   31    Tchana  Albert   92111        Locataire
# 18           19   23  Tchuente    Isis  113000        Locataire
# 19           20   24     Yemba  Elodie   10800             Pret
#
#            Travail Grade du pret  Montant du prêt  Taux_interet  \
# 15  Entreprenariat             B            30000         10.65
# 16             CDI             A            35000          7.90
# 17             CDD             F            35000         20.25
# 18  Entreprenariat             D            35000         18.25
# 19             CDD             B             1750         10.99
#
#     Statut_du_pret  Taux_endettement Défaut  Nombre de credit historique
# 15               0              0.06      N                            3
# ...

# %%
#Avoir la liste des colonnes du dataframe
df.columns
# Out:
# Index(['Id_personne', 'Age', 'Nom', 'Prenom', 'Revenu', 'Type de domicile',
#        'Travail', 'Grade du pret', 'Montant du prêt', 'Taux_interet',
#        'Statut_du_pret', 'Taux_endettement', 'Défaut',
#        'Nombre de credit historique'],
#       dtype='object')

# %%
#Avoir le type de données de ma base de données

df.dtypes
# Out:
# Id_personne                      int64
# Age                              int64
# Nom                             object
# Prenom                          object
# Revenu                           int64
# Type de domicile                object
# Travail                         object
# Grade du pret                   object
# Montant du prêt                  int64
# Taux_interet                   float64
# Statut_du_pret                   int64
# Taux_endettement               float64
# Défaut                          object
# Nombre de credit historique      int64
# dtype: object

# %%
# Voir la dimension du tableau
df.shape
# Out:
# (20, 14)

# %% [markdown]
# # Lecture des tableaux pandas

# %% [markdown]
# ## Sélectionner des colonnes

# %%
#Si la variable n'a pas d'espace
df.Id_personne.head(5)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Id_personne, dtype: int64

# %%
#Si la variable a des caractères spéciaux (comme des espaces, tiret, etc.) --->  Cette approche est plus recommandée
df['Type de domicile'].head(5)
# Out:
# 0       Locataire
# 1    Propriétaire
# 2       Locataire
# 3            Pret
# 4            Pret
# Name: Type de domicile, dtype: object

# %%
# Sélectionner plusieurs colonnes
new_df=df[['Type de domicile','Nom']]
new_df.head(4)
# Out:
#   Type de domicile     Nom
# 0        Locataire   Akono
# 1     Propriétaire    Akwa
# 2        Locataire  Arnaud
# 3             Pret     Awa

# %%
#Connaitre les valeurs uniques d'une variable
df['Type de domicile'].unique()
# Out:
# array(['Locataire', 'Propriétaire', 'Pret'], dtype=object)

# %% [markdown]
# ## Sélectionner des lignes

# %%
#Sélectionner des lignes qui respectent une condition uniquement
new_cdi=df[df['Travail']=="CDI"]
new_cdi.head(5)
# Out:
#    Id_personne  Age      Nom    Prenom  Revenu Type de domicile Travail  \
# 0            1   40    Akono    Nathan   59000        Locataire     CDI
# 1            2   35     Akwa     Aicha   70000     Propriétaire     CDI
# 3            4   23      Awa     Marie   44000             Pret     CDI
# 4            5   24   Dubois  Lachaise   54400             Pret     CDI
# 6            7   44  Ekounou       Eli   77100     Propriétaire     CDI
#
#   Grade du pret  Montant du prêt  Taux_interet  Statut_du_pret  \
# 0             D            35000         16.02               1
# 1             B             1000         11.14               0
# 3             C            35000         15.23               1
# 4             C            35000         14.27               1
# 6             B            35000         12.42               1
#
#    Taux_endettement Défaut  Nombre de credit historique
# 0              0.59      Y                            3
# ...

# %%
#Sélectionner des lignes avec plusieurs conditions
new_pret=df[(df['Travail']=="CDI") & (df['Grade du pret']=="D")]
new_pret.head(5)
# Out:
#    Id_personne  Age       Nom  Prenom  Revenu Type de domicile Travail  \
# 0            1   40     Akono  Nathan   59000        Locataire     CDI
# 9           10   50  Mvog-ada  Bertin   80000     Propriétaire     CDI
#
#   Grade du pret  Montant du prêt  Taux_interet  Statut_du_pret  \
# 0             D            35000         16.02               1
# 9             D             1600         14.74               1
#
#    Taux_endettement Défaut  Nombre de credit historique
# 0              0.59      Y                            3
# 9              0.16      N                            3

# %% [markdown]
# ## Indexation avec iloc (index location)

# %%
# Sélection de la première ligne
df.iloc[0]
# Out:
# Id_personne                            1
# Age                                   40
# Nom                                Akono
# Prenom                            Nathan
# Revenu                             59000
# Type de domicile               Locataire
# Travail                              CDI
# Grade du pret                          D
# Montant du prêt                    35000
# Taux_interet                       16.02
# Statut_du_pret                         1
# Taux_endettement                    0.59
# Défaut                                 Y
# Nombre de credit historique            3
# Name: 0, dtype: object

# %%
# Sélectionner la dernière colone
df.iloc[-1]
# Out:
# Id_personne                        20
# Age                                24
# Nom                             Yemba
# Prenom                         Elodie
# Revenu                          10800
# Type de domicile                 Pret
# Travail                           CDD
# Grade du pret                       B
# Montant du prêt                  1750
# Taux_interet                    10.99
# Statut_du_pret                      1
# Taux_endettement                 0.16
# Défaut                              N
# Nombre de credit historique         2
# Name: 19, dtype: object

# %%
#Sélectionner les deux premières lignes et les deux première colonnes

df.iloc[0:2,0:2]
# Out:
#    Id_personne  Age
# 0            1   40
# 1            2   35

# %% [markdown]
# ## Indexation avec loc (accéder aux éléments à partir des label)

# %%
#Création d'un index dans le dataframe df_etudiant

# df =df.set_index("Nom") # On utilise la colonne "Nom" comme index
df
# Pour réinitialiser l'index
# df=df.reset_index()
# Out:
#           Id_personne  Age     Prenom  Revenu Type de domicile  \
# Nom
# Akono               1   40     Nathan   59000        Locataire
# Akwa                2   35      Aicha   70000     Propriétaire
# Arnaud              3   25      Matin    9600        Locataire
# Awa                 4   23      Marie   44000             Pret
# Dubois              5   24   Lachaise   54400             Pret
# Durand              6   21     Bertin    9900        Locataire
# Ekounou             7   44        Eli   77100     Propriétaire
# Mendong             8   24       Zibi   33000        Locataire
# Moussa              9   24     Hamado   24000        Locataire
# Mvog-ada           10   50     Bertin   80000     Propriétaire
# Mvogo              11   22    Melanie   25000        Locataire
# Neba               12   21   Charlène   10000        Locataire
# Ngo                13   34  Stephanie   95000             Pret
# Ngono              14   26      Marie  108160             Pret
# ...

# %%
df.loc["Akono"] # Sélectionner la ligne avec l'index "Akono"
# Out:
# Id_personne                            1
# Age                                   40
# Prenom                            Nathan
# Revenu                             59000
# Type de domicile               Locataire
# Travail                              CDI
# Grade du pret                          D
# Montant du prêt                    35000
# Taux_interet                       16.02
# Statut_du_pret                         1
# Taux_endettement                    0.59
# Défaut                                 Y
# Nombre de credit historique            3
# Name: Akono, dtype: object

# %%
#Sélection de la ligne Mendong
df.loc["Mendong"]
# Out:
# Id_personne                            8
# Age                                   24
# Prenom                              Zibi
# Revenu                             33000
# Type de domicile               Locataire
# Travail                              CDI
# Grade du pret                          B
# Montant du prêt                    35000
# Taux_interet                       11.11
# Statut_du_pret                         1
# Taux_endettement                    0.44
# Défaut                                 N
# Nombre de credit historique            4
# Name: Mendong, dtype: object

# %% [markdown]
# # Statistiques descriptives

# %% [markdown]
# ## Obtenir des statistiques de base (moyenne, médiane, écart-type)

# %%
#Description des variables quantitatives
df.describe().T
# Out:
#                              count        mean            std      min  \
# Id_personne                   20.0     10.5000       5.916080     1.00
# Age                           20.0     28.4500       8.274724    21.00
# Revenu                        20.0  82503.5500  105576.833252  9600.00
# Montant du prêt               20.0  25092.5000   15036.274341  1000.00
# Taux_interet                  20.0     12.2535       3.899438     7.14
# Statut_du_pret                20.0      0.8000       0.410391     0.00
# Taux_endettement              20.0      0.3525       0.154507     0.06
# Nombre de credit historique   20.0      3.0500       0.887041     2.00
#
#                                     25%        50%         75%        max
# Id_personne                      5.7500     10.500     15.2500      20.00
# Age                             23.0000     24.000     32.5000      50.00
# Revenu                       24750.0000  64500.000  98290.0000  500000.00
# ...

# %% [markdown]
# ## Compter les valeurs uniques et les fréquences

# %%
#Description des variables qualitatives
df.describe(include="object").T
# Out:
#                  count unique        top freq
# Prenom              20     18     Bertin    2
# Type de domicile    20      3  Locataire   10
# Travail             20      3        CDI   11
# Grade du pret       20      6          B    6
# Défaut              20      2          N   18

# %%
# Compter les valeurs manquantes par variable 
df.isnull().mean()  
# Compter les valeurs manquantes par ligne
#df.isnull().sum(axis=1).head(5) 
# Compter les valeurs manquantes par variable
#df.isnull().sum()
# Compter les valeurs uniques par variable
#df.nunique()    
# Compter les valeurs uniques par variable
#df['Type de domicile'].nunique()    
# Compter les valeurs uniques par variable
#df['Type de domicile'].value_counts()    # Compter les valeurs uniques et afficher leur fréquence
# Compter les valeurs uniques par variable      
#df['Type de domicile'].value_counts(normalize=True)  # Compter les valeurs uniques et afficher leur fréquence relative  
# Compter les valeurs uniques par variable
#df['Type de domicile'].value_counts(dropna=False)  # Compter les valeurs uniques et afficher leur fréquence, y compris les valeurs manquantes   
# Compter les valeurs uniques par variable
#df['Type de domicile'].value_counts(dropna=False, normalize=True)  # Compter les valeurs uniques et afficher leur fréquence relative, y compris les valeurs manquantes  
# Compter les valeurs uniques par variable
#df['Type de domicile'].value_counts().sort_index()  # Compter les valeurs uniques et trier par index
# Compter les valeurs uniques par variable 
#df['Type de domicile'].value_counts().sort_values()  # Compter les valeurs uniques et trier par fréquence
# Compter les valeurs uniques par variable
#df['Type de domicile'].value_counts().sort_values(ascending=False)  # Compter les valeurs uniques et trier par fréquence décroissante
# Compter les valeurs uniques par variable
#df['Type de domicile'].value_counts().sort_values(ascending=True)  # Compter les valeurs uniques et trier par fréquence croissante
# Compter les valeurs uniques par variable
#df['Type de domicile'].value_counts().sort_index(ascending=False)  # Compter les valeurs uniques et trier par index décroissant
# Compter les valeurs uniques par variable  
#df['Type de domicile'].value_counts().sort_index(ascending=True)  # Compter les valeurs uniques et trier par index croissant
# Compter les valeurs uniques par variable
#df['Type de domicile'].value_counts().sort_index(ascending=True, na_position='last')  # Compter les valeurs uniques et trier par index croissant, en plaçant les valeurs manquantes à la fin
# Compter les valeurs uniques par variable
#df['Type de domicile'].value_counts().sort_index(ascending=True, na_position='first')  # Compter les valeurs uniques et trier par index croissant, en plaçant les valeurs manquantes au début
# Out:
# Id_personne                    0.0
# Age                            0.0
# Prenom                         0.0
# Revenu                         0.0
# Type de domicile               0.0
# Travail                        0.0
# Grade du pret                  0.0
# Montant du prêt                0.0
# Taux_interet                   0.0
# Statut_du_pret                 0.0
# Taux_endettement               0.0
# Défaut                         0.0
# Nombre de credit historique    0.0
# dtype: float64

# %% [markdown]
# # Modifier les données

# %% [markdown]
# ## Suppression des lignes

# %%
#Suppression des lignes ayant des données manquantes
df.dropna(inplace=True)
df
# Out:
#           Id_personne  Age     Prenom  Revenu Type de domicile  \
# Nom
# Akono               1   40     Nathan   59000        Locataire
# Akwa                2   35      Aicha   70000     Propriétaire
# Arnaud              3   25      Matin    9600        Locataire
# Awa                 4   23      Marie   44000             Pret
# Dubois              5   24   Lachaise   54400             Pret
# Durand              6   21     Bertin    9900        Locataire
# Ekounou             7   44        Eli   77100     Propriétaire
# Mendong             8   24       Zibi   33000        Locataire
# Moussa              9   24     Hamado   24000        Locataire
# Mvog-ada           10   50     Bertin   80000     Propriétaire
# Mvogo              11   22    Melanie   25000        Locataire
# Neba               12   21   Charlène   10000        Locataire
# Ngo                13   34  Stephanie   95000             Pret
# Ngono              14   26      Marie  108160             Pret
# ...

# %% [markdown]
# ## Suppression des colonnes

# %%
#Supprimer une colonne

df.drop("Revenu",axis=1)
# Out:
#           Id_personne  Age     Prenom Type de domicile         Travail  \
# Nom
# Akono               1   40     Nathan        Locataire             CDI
# Akwa                2   35      Aicha     Propriétaire             CDI
# Arnaud              3   25      Matin        Locataire             CDD
# Awa                 4   23      Marie             Pret             CDI
# Dubois              5   24   Lachaise             Pret             CDI
# Durand              6   21     Bertin        Locataire             CDD
# Ekounou             7   44        Eli     Propriétaire             CDI
# Mendong             8   24       Zibi        Locataire             CDI
# Moussa              9   24     Hamado        Locataire             CDI
# Mvog-ada           10   50     Bertin     Propriétaire             CDI
# Mvogo              11   22    Melanie        Locataire             CDD
# Neba               12   21   Charlène        Locataire             CDD
# ...

# %% [markdown]
# ## Créer une nouvelle colonne calculer à partir d'autres

# %%
#Création d'une nouvelle variable comme étant la multiplication de deux colonnes du tableau
df["test"]=df["Montant du prêt"]*df["Taux_interet"]
df
# Out:
#           Id_personne  Age     Prenom  Revenu Type de domicile  \
# Nom
# Akono               1   40     Nathan   59000        Locataire
# Akwa                2   35      Aicha   70000     Propriétaire
# Arnaud              3   25      Matin    9600        Locataire
# Awa                 4   23      Marie   44000             Pret
# Dubois              5   24   Lachaise   54400             Pret
# Durand              6   21     Bertin    9900        Locataire
# Ekounou             7   44        Eli   77100     Propriétaire
# Mendong             8   24       Zibi   33000        Locataire
# Moussa              9   24     Hamado   24000        Locataire
# Mvog-ada           10   50     Bertin   80000     Propriétaire
# Mvogo              11   22    Melanie   25000        Locataire
# Neba               12   21   Charlène   10000        Locataire
# Ngo                13   34  Stephanie   95000             Pret
# Ngono              14   26      Marie  108160             Pret
# ...

# %% [markdown]
# ## Mettre à jour une colonne

# %%
#Mettre à jour avec une valeur pour toutes les lignes
df["test"]=100
df
# Out:
#           Id_personne  Age     Prenom  Revenu Type de domicile  \
# Nom
# Akono               1   40     Nathan   59000        Locataire
# Akwa                2   35      Aicha   70000     Propriétaire
# Arnaud              3   25      Matin    9600        Locataire
# Awa                 4   23      Marie   44000             Pret
# Dubois              5   24   Lachaise   54400             Pret
# Durand              6   21     Bertin    9900        Locataire
# Ekounou             7   44        Eli   77100     Propriétaire
# Mendong             8   24       Zibi   33000        Locataire
# Moussa              9   24     Hamado   24000        Locataire
# Mvog-ada           10   50     Bertin   80000     Propriétaire
# Mvogo              11   22    Melanie   25000        Locataire
# Neba               12   21   Charlène   10000        Locataire
# Ngo                13   34  Stephanie   95000             Pret
# Ngono              14   26      Marie  108160             Pret
# ...

# %% [markdown]
# ## Mettre à jour une valeur

# %%
#Mise à jour de la dernière colonne de la première ligne
df.iloc[0,-1]=100000
df
# Out:
#           Id_personne  Age     Prenom  Revenu Type de domicile  \
# Nom
# Akono               1   40     Nathan   59000        Locataire
# Akwa                2   35      Aicha   70000     Propriétaire
# Arnaud              3   25      Matin    9600        Locataire
# Awa                 4   23      Marie   44000             Pret
# Dubois              5   24   Lachaise   54400             Pret
# Durand              6   21     Bertin    9900        Locataire
# Ekounou             7   44        Eli   77100     Propriétaire
# Mendong             8   24       Zibi   33000        Locataire
# Moussa              9   24     Hamado   24000        Locataire
# Mvog-ada           10   50     Bertin   80000     Propriétaire
# Mvogo              11   22    Melanie   25000        Locataire
# Neba               12   21   Charlène   10000        Locataire
# Ngo                13   34  Stephanie   95000             Pret
# Ngono              14   26      Marie  108160             Pret
# ...

# %% [markdown]
# ## Mettre à jour des valeurs qui respectent une condition

# %%
#Modifier la valeur de la colonne d'une ligne en fonction d'une condition (remplacer D par F loan_grade)

df.loc[df["Travail"]=="CDI","Travail"]="CDD"
df
# Out:
#           Id_personne  Age     Prenom  Revenu Type de domicile  \
# Nom
# Akono               1   40     Nathan   59000        Locataire
# Akwa                2   35      Aicha   70000     Propriétaire
# Arnaud              3   25      Matin    9600        Locataire
# Awa                 4   23      Marie   44000             Pret
# Dubois              5   24   Lachaise   54400             Pret
# Durand              6   21     Bertin    9900        Locataire
# Ekounou             7   44        Eli   77100     Propriétaire
# Mendong             8   24       Zibi   33000        Locataire
# Moussa              9   24     Hamado   24000        Locataire
# Mvog-ada           10   50     Bertin   80000     Propriétaire
# Mvogo              11   22    Melanie   25000        Locataire
# Neba               12   21   Charlène   10000        Locataire
# Ngo                13   34  Stephanie   95000             Pret
# Ngono              14   26      Marie  108160             Pret
# ...

# %% [markdown]
# # Fusion et jointure de Data Frames

# %%
# Création des DataFrames exemple
data1 = {
    "ID": [1, 2, 3, 4],
    "Prénom": ["Alice", "Bob", "Charlie", "David"]
}

data2 = {
    "ID": [3, 4, 5, 6],
    "Ville": ["Paris", "Lyon", "Marseille", "Toulouse"]
}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# Effectuer une jointure interne (inner join)
inner_join = df1.merge(df2, on="ID", how="inner")

# Effectuer une jointure externe (outer join)
outer_join = df1.merge(df2, on="ID", how="outer")

# Effectuer une jointure gauche (left join)
left_join = df1.merge(df2, on="ID", how="left")

# Effectuer une jointure droite (right join)
right_join = df1.merge(df2, on="ID", how="right")

# Afficher les résultats
print("Inner join:")
print(inner_join)
print("\nOuter join:")
print(outer_join)
print("\nLeft join:")
print(left_join)
print("\nRight join:")
print(right_join)
# Out:
# Inner join:
#    ID   Prénom  Ville
# 0   3  Charlie  Paris
# 1   4    David   Lyon
#
# Outer join:
#    ID   Prénom      Ville
# 0   1    Alice        NaN
# 1   2      Bob        NaN
# 2   3  Charlie      Paris
# 3   4    David       Lyon
# 4   5      NaN  Marseille
# 5   6      NaN   Toulouse
#
# Left join:
#    ID   Prénom  Ville
# 0   1    Alice    NaN
# 1   2      Bob    NaN
# 2   3  Charlie  Paris
# 3   4    David   Lyon
#
# Right join:
#    ID   Prénom      Ville
# 0   3  Charlie      Paris
# 1   4    David       Lyon
# 2   5      NaN  Marseille
# 3   6      NaN   Toulouse

# %% [markdown]
# # Enregistrer la base

# %% [markdown]
# ## Enregistrer en csv

# %%
# Enregistrer en csv
#df.to_csv("test.csv")

# %% [markdown]
# ## Enregistrer en JSON

# %%
# Exporter en fichier json
#df.to_json("test.json")
